# %%
import pandas as pd

# %%
df_bookinghotel=pd.read_csv("fact_bookings.csv")

# %%
df_bookinghotel.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
df_bookinghotel.shape
# Out:
# (134590, 12)

# %%
df_bookinghotel.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %% [markdown]
# #TO FIND BOOKINGS MADE THROUGH INDIVIDUAL PLATFORM PER PERSON USE VALUE_COUNTS() FUNCTION

# %%
df_bookinghotel.booking_platform.value_counts()
# Out:
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: booking_platform, dtype: int64

# %%
df_bookinghotel.booking_platform.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df_bookinghotel.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_date=pd.read_csv("dim_date.csv")
df_hotels=pd.read_csv("dim_hotels.csv")
df_rooms=pd.read_csv("dim_rooms.csv")
df_factaggregratedbookings=pd.read_csv("fact_aggregated_bookings.csv")

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_hotels.city.value_counts()
# Out:
# Mumbai       8
# Bangalore    6
# Hyderabad    6
# Delhi        5
# Name: city, dtype: int64

# %%
df_hotels.city.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df_bookinghotel[df_bookinghotel.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_booking=df_bookinghotel[df_bookinghotel.no_guests>0]

# %%
df_booking
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_booking.shape
# Out:
# (134578, 12)

# %%
df_booking.revenue_generated.min(),df_booking.revenue_generated.max(),
# Out:
# (6500, 28560000)

# %%
avg,sd=df_booking.revenue_generated.mean(),df_booking.revenue_generated.std()

# %%
avg,sd
# Out:
# (15378.036937686695, 93040.15493143328)

# %%
higher_limitvalue=avg+3*sd

# %%
higher_limitvalue
# Out:
# 294498.50173198653

# %%
lower_limitvalue=avg-3*sd
lower_limitvalue
# Out:
# -263742.4278566132

# %%
df_booking[df_booking.revenue_generated>higher_limitvalue]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_booking=df_booking[df_booking.revenue_generated<higher_limitvalue]

# %%
df_booking
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_booking.shape
# Out:
# (134573, 12)

# %%
df_booking[df_booking.room_category=="RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
df_booking.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# ### data transformation

# %%
import pandas as pd

# %%
df_factaggregratedbookings=pd.read_csv("fact_aggregated_bookings.csv")

# %%
df_factaggregratedbookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %%
df_factaggregratedbookings.shape
# Out:
# (9200, 5)

# %%
df_factaggregratedbookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_factaggregratedbookings["occupancyper"]=df_factaggregratedbookings["successful_bookings"]/df_factaggregratedbookings["capacity"]

# %%
df_factaggregratedbookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occupancyper
# 0      0.833333
# 1      0.933333
# 2      0.766667
# 3      1.578947
# 4      0.947368

# %%
df_factaggregratedbookings["occupancyper"]=df_factaggregratedbookings["occupancyper"].apply(lambda x:round(x*100,2))

# %%
df_factaggregratedbookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancyper
# 0            83.33
# ...

# %% [markdown]
# #### 1. what are the average occupancy rate in each of the room categories?

# %%
df_factaggregratedbookings.groupby("room_category")["occupancyper"].mean()
# Out:
# room_category
# RT1    58.224247
# RT2    58.040278
# RT3    58.028213
# RT4    59.300461
# Name: occupancyper, dtype: float64

# %%
df_rooms=pd.read_csv("dim_rooms.csv")

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df=pd.merge(df_factaggregratedbookings,df_rooms,left_on="room_category",right_on="room_id")

# %%
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancyper room_id    room_class
# ...

# %%
df.groupby("room_class")["occupancyper"].mean()
# Out:
# room_class
# Elite           58.040278
# Premium         58.028213
# Presidential    59.300461
# Standard        58.224247
# Name: occupancyper, dtype: float64

# %%
df.drop("room_id",axis=1,inplace=True)

# %%
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occupancyper    room_class
# ...

# %% [markdown]
# ### 2. print average occupancy per city

# %%
df_hotels=pd.read_csv("dim_hotels.csv")
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df=pd.merge(df,df_hotels, on="property_id")

# %%
df=pd.merge(df,df_hotels, on="property_id")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-c2e4d6d3d4f8> in <module>
# ----> 1 df=pd.merge(df,df_hotels, on="property_id")
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     596         validate=None,
#     597     ):
# --> 598         _left = _validate_operand(left)
#     599         _right = _validate_operand(right)
#     600         self.left = self.orig_left = _left
#
# ...

# %%
df

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
#
#    occupancyper room_class property_name_x category_x  city_x property_name_y  \
# 0         83.33   Standard   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 1         66.67   Standard   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 2         56.67   Standard   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
#
#   category_y  city_y  property_name category    city
# 0     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 1     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 2     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai

# %%
df

# %%
df.groupby("city")["occupancyper"].mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-fa6af0224773> in <module>
# ----> 1 df.groupby("city")["occupancyper"].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'groupby'

# %%
df.groupby("city")["occupancyper"].mean(1)
# Out:
# city
# Bangalore    56.594207
# Delhi        61.606467
# Hyderabad    58.144651
# Mumbai       57.936305
# Name: occupancyper, dtype: float64

# %%
df.groupby("city")["occupancyper"].mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='city'>

# %% [markdown]
# 3.when was the occupancy better weekend or weekday?

# %%
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
#
#    occupancyper room_class property_name_x category_x  city_x property_name_y  \
# 0         83.33   Standard   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 1         66.67   Standard   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 2         56.67   Standard   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
#
#   category_y  city_y  property_name category    city
# 0     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 1     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 2     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai

# %%
df=pd.merge(df,df_date,left_on="check_in_date",right_on="date")

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
#
#    occupancyper room_class property_name_x category_x  city_x property_name_y  \
# 0         60.00   Standard   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 1         60.98      Elite   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
# 2         62.50    Premium   Atliq Exotica     Luxury  Mumbai   Atliq Exotica
#
#   category_y  city_y  property_name category    city       date  mmm yy  \
# 0     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
# 1     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
# 2     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# ...

# %%
df.groupby("day_type")["occupancyper"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occupancyper, dtype: float64

# %% [markdown]
# 4. In month of july what is the occupancy percentage for different city

# %%
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_july=df[df["mmm yy"]=="Jul 22"]
df_july.head(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 4300        16559     10-Jul-22           RT1                   26      30.0
# 4301        16559     10-Jul-22           RT2                   38      41.0
# 4302        16559     10-Jul-22           RT3                   28      32.0
# 4303        16559     10-Jul-22           RT4                   17      18.0
#
#       occupancyper    room_class property_name_x category_x  city_x  \
# 4300         86.67      Standard   Atliq Exotica     Luxury  Mumbai
# 4301         92.68         Elite   Atliq Exotica     Luxury  Mumbai
# 4302         87.50       Premium   Atliq Exotica     Luxury  Mumbai
# 4303         94.44  Presidential   Atliq Exotica     Luxury  Mumbai
#
#      property_name_y category_y  city_y  property_name category    city  \
# 4300   Atliq Exotica     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# 4301   Atliq Exotica     Luxury  Mumbai  Atliq Exotica   Luxury  Mumbai
# ...

# %%
df_july.groupby("city")["occupancyper"].mean().sort_values(ascending=False)
# Out:
# city
# Delhi        59.177886
# Hyderabad    55.357955
# Mumbai       55.235469
# Bangalore    54.073939
# Name: occupancyper, dtype: float64

# %%
df_august=pd.read_csv("new_data_august.csv")

# %%
df_august
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
# 5        17561      Atliq Blu    Luxury     Mumbai           RT1   Standard
# 6        17564  Atliq Seasons  Business     Mumbai           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# ...

# %%
latest_df=pd.concat([df,df_august],ignore_index=True,axis=0)
latest_df.tail(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occupancyper room_class property_name_x category_x city_x  ...  \
# 6503           NaN   Standard             NaN        NaN    NaN  ...
# 6504           NaN   Standard             NaN        NaN    NaN  ...
# 6505           NaN   Standard             NaN        NaN    NaN  ...
# 6506           NaN   Standard             NaN        NaN    NaN  ...
#
#      category_y city_y  property_name  category       city date  mmm yy  \
# 6503        NaN    NaN   Atliq Grands    Luxury  Bangalore  NaN  Aug-22
# 6504        NaN    NaN     Atliq City  Business  Bangalore  NaN  Aug-22
# ...

# %%
latest_df.shape
# Out:
# (6507, 21)

# %% [markdown]
# 6.print revenue  realized  per city

# %%
df_booking.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920
# 5               9100              9100
# 6               9100              3640

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df1bookings=pd.merge(df_booking,df_hotels,on="property_id")
df1bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# ...

# %%
df1bookings.groupby("city")["revenue_generated"].sum().round(2).sort_values(ascending=False)
# Out:
# city
# Mumbai       784786980
# Bangalore    494814675
# Hyderabad    381333250
# Delhi        346350550
# Name: revenue_generated, dtype: int64

# %% [markdown]
# 7.print month by month revenue

# %%
df1bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# ...

# %%
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
df_print=pd.merge(df1bookings,df_date,left_on="check_in_date",right_on="date")

# %%
df_print
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
df1bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_date["date"]=pd.to_datetime(df_date["date"])
df_date["date"].head(4)
# Out:
# 0   2022-05-01
# 1   2022-05-02
# 2   2022-05-03
# 3   2022-05-04
# Name: date, dtype: datetime64[ns]

# %%
df1bookings["check_in_date"]= pd.to_datetime(df1bookings["check_in_date"])
df1bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-01-05      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-01-05      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-01-05      3/5/2022
# 3  May012216558RT17        16558     28-04-22    2022-01-05      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# ...

# %%
df1bookings.info(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_print=pd.merge(df1bookings,df_date,left_on="check_in_date",right_on="date")

# %%
df_print.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
# 3  May052216558RT14        16558     3/5/2022    2022-05-05      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
# 3        2.0           RT1         tripster            3.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# ...

# %%
df_print.groupby("mmm yy")["revenue_generated"].sum().sort_values(ascending=True)
# Out:
# mmm yy
# Jun 22    443905310
# Jul 22    457830390
# May 22    479275250
# Name: revenue_generated, dtype: int64
